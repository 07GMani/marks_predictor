# %%
import pandas as pd
df=pd.read_csv("student_habits_performance.csv")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
import numpy as np #handles array
# !pip install matplotlib
# !pip install seaborn
import matplotlib.pyplot as plt #handles plating
import seaborn as sns #handles building on matplotlib for better style

# %%
sns.set(style="whitegrid") #setting seaborn style plot

# %%
df.isna() #returns T/F for emptyness for each cell
# Out:
#      student_id    age  gender  study_hours_per_day  social_media_hours  \
# 0         False  False   False                False               False
# 1         False  False   False                False               False
# 2         False  False   False                False               False
# 3         False  False   False                False               False
# 4         False  False   False                False               False
# ..          ...    ...     ...                  ...                 ...
# 995       False  False   False                False               False
# 996       False  False   False                False               False
# 997       False  False   False                False               False
# 998       False  False   False                False               False
# 999       False  False   False                False               False
#
#      netflix_hours  part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.isna().sum().sum() #counts total no. of missing cells
# Out:
# np.int64(91)

# %%
df.dropna(inplace=True) #dropping of empty cells

# %%
df.isna()
df.isna().sum().sum() #find no false rows bca permanent hata diya gya using inplace=True
# Out:
# np.int64(0)

# %%
df.duplicated()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
df.describe(include="object") #shows summary of table(mean,median,std)
# Out:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1000   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %%
categorical_cols = ["gender","part_time_job","diet_quality","parental_education_level", "internet_quality", "extracurricular_participation"]

# %%
df.describe(include="object").columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
for col in categorical_cols:
    print(f"Value Count for {col}: \n {df[col].value_counts()}")
    
#prints freq of each unique value per col
# Out:
# Value Count for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# Value Count for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# Value Count for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# Value Count for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# Value Count for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# Value Count for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
#plots of histogram for numeric cols
df.hist(bins=20, edgecolor="black")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
    sns.countplot(data=df, x=col)
    plt.title("Distribution of {col}")
    plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f") #corr -> co-relation
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
#features selection and encoding
num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours', 'attendance_percentage', 'sleep_hours', 'exercise_frequency', 'mental_health_rating', 'exam_score']
for feature in num_features:
    sns.scatterplot(data = df, x=feature, y="exam_score")
    plt.title(f"{feature} vs Exam Score")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours', 'attendance_percentage', 'sleep_hours', 'exercise_frequency', 'mental_health_rating', 'exam_score']
#       2 for feature in num_features:
# ----> 3     sns.scatterplot(data = df, x=feature, y="exam_score")
#       4     plt.title(f"{feature} vs Exam Score")
#       5     plt.show()
#
# NameError: name 'sns' is not defined

# %%
for col in categorical_cols:
    sns.boxplot(data = df, x=col,y="exam_score")
    plt.title(f"Exam Score by {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
#starting setup ML Model
# !pip install scikit-learn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
features = ["study_hours_per_day","attendance_percentage","mental_health_rating", "sleep_hours","part_time_job" ]

# %%
target = "exam_score"

# %%
df_model = df[features+[target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# ...

# %%
le = LabelEncoder()

# %%
df_model["part_time_job"] = le.fit_transform(df_model["part_time_job"]) #part_tiem_job converted to 0 or 1 based on yes or no

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# ...

# %%
X = df_model[features]

# %%
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression": {
        "model":LinearRegression(),
        "params":{}
    },
    "DecisionTree": {
        "model":DecisionTreeRegressor(),
        "params":{"max_depth":[3,5,9],"min_samples_split":[2,5]}
    },
    "RandomForest":{
        "model":RandomForestRegressor(),
        "params":{"n_estimators": [50,100], "max_depth":[5,10]}
    }
}

# %%
best_models = []

# %%
best_models = []

for name, config in models.items():
    print(f"Training {name}")

    grid = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
    grid.fit(X_train, y_train)

    y_pred = grid.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    best_models.append({
        "model": name,
        "best_params": grid.best_params_,
        "rmse": rmse,
        "r2": r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
results_df = pd.DataFrame(best_models)
results_df
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  7.272064
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  8.878959
# 2      RandomForest     {'max_depth': 5, 'n_estimators': 100}  7.921104
#
#          r2
# 0  0.830527
# 1  0.747356
# 2  0.798926

# %%
results_df.sort_values(by="rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  7.272064
# 2      RandomForest     {'max_depth': 5, 'n_estimators': 100}  7.921104
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  8.878959
#
#          r2
# 0  0.830527
# 2  0.798926
# 1  0.747356

# %%
import joblib

best_row = results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                   7.272064
# r2                     0.830527
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]#.set_params(**best_row["best_params"])

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
final_model.predict(X_test)
# Out:
# array([ 68.30053395,  72.25779551,  57.96780871,  47.10026421,
#         76.55263164,  47.5688949 ,  59.88818359,  57.380995  ,
#         98.26310392,  83.39081928,  63.58381267,  83.15536594,
#         76.53481528,  67.56464235, 100.91762465,  61.46176878,
#         70.5947591 ,  86.85962666,  53.21270007,  80.85364674,
#         73.19341212,  79.7245903 ,  66.31366546,  79.7513049 ,
#         62.15277743,  79.32808448,  58.73539837,  70.52672235,
#         36.59323364,  56.84795774,  63.42570115,  83.12680365,
#         75.85209083,  74.53698275,  71.17382137,  77.0077602 ,
#         67.54393569,  64.7719743 ,  51.42035996,  80.46322951,
#         51.31066723,  54.2248526 ,  44.72178483,  81.50258474,
#         97.86319106,  84.3068876 ,  86.75373513,  71.55786423,
#         34.72601698,  68.00488232,  63.2566056 ,  54.04532213,
#         55.03445016,  71.80449683,  69.31005922,  68.29040328,
#         70.58020241,  83.02517528,  87.69201972,  74.55553431,
# ...

# %%
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 68.30053395,  72.25779551,  57.96780871,  47.10026421,
#         76.55263164,  47.5688949 ,  59.88818359,  57.380995  ,
#         98.26310392,  83.39081928,  63.58381267,  83.15536594,
#         76.53481528,  67.56464235, 100.91762465,  61.46176878,
#         70.5947591 ,  86.85962666,  53.21270007,  80.85364674,
#         73.19341212,  79.7245903 ,  66.31366546,  79.7513049 ,
#         62.15277743,  79.32808448,  58.73539837,  70.52672235,
#         36.59323364,  56.84795774,  63.42570115,  83.12680365,
#         75.85209083,  74.53698275,  71.17382137,  77.0077602 ,
#         67.54393569,  64.7719743 ,  51.42035996,  80.46322951,
#         51.31066723,  54.2248526 ,  44.72178483,  81.50258474,
#         97.86319106,  84.3068876 ,  86.75373513,  71.55786423,
#         34.72601698,  68.00488232,  63.2566056 ,  54.04532213,
#         55.03445016,  71.80449683,  69.31005922,  68.29040328,
#         70.58020241,  83.02517528,  87.69201972,  74.55553431,
# ...
